euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# Function to initialize centroids randomly
def initialize_centroids(data, k):
    centroids = data.copy()
    np.random.shuffle(centroids)
    return centroids[:k]

# Function to assign each data point to the nearest centroid
def assign_clusters(data, centroids):
    clusters = {}
    for point in data:
        closest_centroid_index = np.argmin([euclidean_distance(point, centroid) for centroid in centroids])
        if closest_centroid_index not in clusters:
            clusters[closest_centroid_index] = []
        clusters[closest_centroid_index].append(point)
    return clusters

# Function to update centroids based on cluster means
def update_centroids(clusters):
    centroids = []
    for cluster in clusters.values():
        cluster_mean = np.mean(cluster, axis=0)
        centroids.append(cluster_mean)
    return np.array(centroids)

# Function to compute inertia
def compute_inertia(clusters, centroids):
    inertia = 0
    for i, cluster in clusters.items():
        inertia += np.sum((np.array(cluster) - centroids[i]) ** 2)
    return inertia

# Function to compute Dunn Index
def compute_dunn_index(data, clusters, centroids):
    max_intra_cluster_distance = max([np.max([euclidean_distance(p1, p2) for p1 in cluster for p2 in cluster]) for cluster in clusters.values()])
    min_inter_cluster_distance = min([euclidean_distance(centroids[i], centroids[j]) for i in range(len(centroids)) for j in range(i+1, len(centroids))])
    return min_inter_cluster_distance / max_intra_cluster_distance


# Main function to perform k-means clustering
def kmeans(data, k, max_iters=100):
    # Initialize centroids
    centroids = initialize_centroids(data, k)
    # Initialize previous centroids for convergence check
    prev_centroids = None
    for _ in range(max_iters):
        # Assign clusters
        clusters = assign_clusters(data, centroids)
        # Update centroids
        prev_centroids = centroids
        centroids = update_centroids(clusters)
        # Check for convergence
        if np.array_equal(prev_centroids, centroids):
            break
    # Compute inertia
    inertia = compute_inertia(clusters, centroids)
    # Compute Dunn Index
    dunn_index = compute_dunn_index(data, clusters, centroids)
    return clusters, centroids, inertia, dunn_index


# Define the range of k values
k_values = range(2, 11)

# Initialize lists to store results
dunn_indices = []
inertias = []

# Iterate over each k
for k in k_values:
    # Perform k-means clustering
    clusters, centroids, inertia, dunn_index = kmeans(combined_data.values, k)
    # Append results to lists
    dunn_indices.append(dunn_index)
    inertias.append(inertia)

# Print the results table
print("K | Dunn Index | Inertia")
for i in range(len(k_values)):
    print(f"{k_values[i]} | {dunn_indices[i]:.6f} | {inertias[i]:.6f}")
# Out:
# K | Dunn Index | Inertia
# 2 | 1.017241 | 493039335348780.375000
# 3 | 0.919410 | 243116058190689.218750
# 4 | 0.878148 | 134837801048303.156250
# 5 | 0.800071 | 88443640372442.718750
# 6 | 0.700021 | 68302894745491.554688
# 7 | 0.692390 | 52471760308793.250000
# 8 | 0.810847 | 37878712531025.929688
# 9 | 0.609717 | 33091793953571.750000
# 10 | 0.489626 | 30202976899082.792969

# %%
import matplotlib.pyplot as plt

def visualize_clusters(data, clusters, centroids):
    plt.figure(figsize=(8, 6))
    colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k']  # You can extend this list for more clusters
    for i, cluster in clusters.items():
        cluster_data = np.array(cluster)
        plt.scatter(cluster_data[:, 0], cluster_data[:, 1], c=colors[i], label=f'Cluster {i+1}')
    plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
    plt.xlabel('Household Total Assets')
    plt.ylabel('Annual Household Income')
    plt.title('K-Means Clustering')
    plt.legend()
    plt.grid(True)
    # Adjust axis limits based on the maximum values
    max_assets = combined_data['household_total_assets'].max()
    max_income = combined_data['annual_household_income'].max()
    plt.xlim(0, max_assets + max_assets * 0.1)  # 10% margin on the right
    plt.ylim(0, max_income + max_income * 0.1)  # 10% margin on the top
    plt.show()

# Perform k-means clustering
clusters, centroids, inertia, dunn_index = kmeans(combined_data.values, k=3)

# Visualize clusters and centroids
visualize_clusters(combined_data.values, clusters, centroids)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Given data
data = {
    'household_total_assets': [1230531,4877446,4430878,1954751,2179963,3685318,4675156,447069,3912570,4157580,4238546,4190288,100359,1570630,4423419,1752823,28118,1501102,536790,4488734,2669462,869841,482431,4378149,4089545,854946,375144,1631381,713230,4542203,3749462,1684695,1114895,4115237,4030337,3128781,3760891,636012,504965,987875,1877480,2288447,3968638,2174307,1761030,2106033,4092631,2934935,1586958,471955,218374,3162669,3332342,4836347,2225999,4497205,3472417,2687418,1180962,3260564,3313415,752450,4863420,4622575,850286,585038,4930570,2250196,1493971,2198885,1754703,1076573,1372456,4038127,2720657,3366957,2731348,2741967,3513087,2831641,4582491,4040025,2034506,1183150,1819629,3153017,1206913,2988328,3003535,3685819,3533374,4844314,212275,2972507,3655844,4798360,2090366,2636094,2462624,3765841,3436953,233117,2996665,1638086,4139962,1765937,1442601,3744202,3442011,423420,2972979,4820170,4624242,925078,4001251,1713039,4112338,201007,3793234,2971329,2252882,2369090,3760697,1534081,41669,1466431,2793856,499475,3372873,608922,1961411,763123,58820,2254678,1298821,401486,4257667,4468550,4843714,4766810,4459108,2084813,1557272,1096899,247235,3281446,4020917,2421833,174574,558424,3717325,94189,3738281,564181,4725619,1444770,480676,1381031,268091,4573955,4201545,1489986,1083785,1106701,266836,312875,4579964,323117,4981673,4213677,787153,3956619,2505872,4163719,1657840,2151292,1465873,4587269,3999961,4000709,852080,2086696,3080878,1001865,2985987,3136211,4716693,1001541,4630455,4103855,4373696,2355859,3355806,1953168,3156769,3036674,1333946,3564721,2902876,1727693,3385855,3810419,421634,2729626,4642033,3931096,146661,1719849,4203715,3420653,3060846,176160,3478229,1021084,2655288,1633677,1844565,1804014,105234,1245989,1218315,4256166,3439750,37215,1231852,3323216,1718317,1455612,2583482,388198,3979846,2944326,3870673,2585095,1276,3911527,944579,2666710,4319547,2910584,3378548,924342,3070425,237985,4147019,2845540,1229241,4729183,4601802,98379,4378954,1641046,3527845,3362165,2782805,4005175,2938418,2221938,4128991,4474083,1006284,2070890,4224201,919734,791717,4535969,3464655,3920486,1582339,835311,3531923,4693332,3659540,1043558,4

plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
plt.xlabel('Household Total Assets')
plt.ylabel('Annual Household Income')
plt.title('KMeans Clustering')
plt.legend()
plt.grid(True)
plt.show()

# # Filter data points based on cluster labels
# cluster_0 = df[kmeans.labels_ == 0]
# cluster_1 = df[kmeans.labels_ == 1]
# cluster_2 = df[kmeans.labels_ == 2]

# # Print out the values of the three clusters
# print("Cluster 0:")
# print(cluster_0)
# print("\nCluster 1:")
# print(cluster_1)
# print("\nCluster 2:")
# print(cluster_2)

# Print out the values of the three centroids
print("Centroid 0:")
print(kmeans.cluster_centers_[0])
print("\nCentroid 1:")
print(kmeans.cluster_centers_[1])
print("\nCentroid 2:")
print(kmeans.cluster_centers_[2])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Centroid 0:
# [812599.79299363 147272.66242038]
#
# Centroid 1:
# [4084293.53488372  156232.70284238]
#
# Centroid 2:
# [2415035.44147157  151497.11036789]

# %%
class WeightedNNClassifier:
    def __init__(self):
        pass

    def fit(self, X_train, y_train):
        self.X_train = np.array([X_train[key] for key in X_train])
        self.y_train = np.array([y_train[key] for key in y_train])

    def predict(self, X_test, k=5):
        y_pred = []
        for key in X_test:
            x_test = X_test[key]
            distances = np.sqrt(np.sum((self.X_train - x_test) ** 2, axis=1))
            weights = 1 / distances
            sorted_indices = np.argsort(distances)
            k_nearest_indices = sorted_indices[:k]
            k_nearest_labels = self.y_train[k_nearest_indices]
            weighted_votes = np.bincount(k_nearest_labels.astype(int), weights=weights[k_nearest_indices])
            prediction = np.argmax(weighted_votes)
            y_pred.append(prediction)
        return np.array(y_pred)

# %%
# Assuming df contains both features and labels
X_train = df.iloc[:, :-1].values  # Features
y_train = df.iloc[:, -1].values   # Labels

# Assuming X_test contains test features
# Replace X_test with your actual test data
# X_test = ...

# Create an instance of the WeightedNNClassifier
weighted_nn_classifier = WeightedNNClassifier()

# Fit the classifier to the training data
weighted_nn_classifier.fit(X_train, y_train)

# Predict the labels of the test data
# y_pred = weighted_nn_classifier.predict(X_test)
# Uncomment and replace X_test with your actual test data to use this line
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-6c835d7402b9> in <cell line: 13>()
#      11
#      12 # Fit the classifier to the training data
# ---> 13 weighted_nn_classifier.fit(X_train, y_train)
#      14
#      15 # Predict the labels of the test data
#
# <ipython-input-5-378ae1e0e2a4> in fit(self, X_train, y_train)
#       4
#       5     def fit(self, X_train, y_train):
# ----> 6         self.X_train = np.array([X_train[key] for key in X_train])
#       7         self.y_train = np.array([y_train[key] for key in y_train])
#       8
#
# <ipython-input-5-378ae1e0e2a4> in <listcomp>(.0)
#       4
#       5     def fit(self, X_train, y_train):
# ----> 6         self.X_train = np.array([X_train[key] for key in X_train])
#       7         self.y_train = np.array([y_train[key] for key in y_train])
#       8
#
# ...

# %%
# Assuming df contains both features and labels
X_train = {0: np.array([1, 2, 3, 4, 5]), 1: np.array([2, 3, 4, 5, 6]), 2: np.array([3, 4, 5, 6, 7])}  # Features
y_train = {0: 0, 1: 1, 2: 0}  # Labels

# Assuming X_test contains test features
X_test = {0: np.array([4, 5, 6, 7, 8]), 1: np.array([3, 4, 5, 6, 7])}

# Create and train the weighted nearest neighbor classifier
weighted_nn_classifier = WeightedNNClassifier()
weighted_nn_classifier.fit(X_train, y_train)

# Predict the labels for the test data
y_pred = weighted_nn_classifier.predict(X_test)

print("Predicted labels:", y_pred)
