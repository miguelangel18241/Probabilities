# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelangel18241/Probabilities/blob/main/IKEA_review_Sentiment_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn
import matplotlib.pyplot as plt

# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from google.colab import files
import io

data = files.upload()
# Out:
#      <input type="file" id="files-0fada3ba-de12-4d9b-9ad6-446a8c0eb406" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fada3ba-de12-4d9b-9ad6-446a8c0eb406">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('dataAssessment2_Health_Analytics_COVID.csv')

# %% [markdown]
# IN THIS PROJECT I WILL BE REPRODUCING THE PREDICTIVE MODELS BASED ON THE FOLLOWING BULLET POINTS:**texto en negrita**
# a. Data set description;
# b. Data analysis;
# c. Correlation;
# d. Data pre-processing;
# e. Evaluation metrics, including accuracy, precision, recall and F1 Score;
# f. Results;
# g. Hyperparameter optimisation; and
# h. Comparison of models’ performance.

# %% [markdown]
# A. DATA SET DESCRIPTION:

# %%
description = df.describe()
description
# Out:
#                 id         age    vis_wuhan   from_wuhan        death  \
# count  1085.000000  843.000000  1085.000000  1081.000000  1085.000000
# mean    543.000000   49.483689     0.176959     0.144311     0.058065
# std     313.356825   18.255334     0.381810     0.351567     0.233973
# min       1.000000    0.250000     0.000000     0.000000     0.000000
# 25%     272.000000   35.000000     0.000000     0.000000     0.000000
# 50%     543.000000   51.000000     0.000000     0.000000     0.000000
# 75%     814.000000   64.000000     0.000000     0.000000     0.000000
# max    1085.000000   96.000000     1.000000     1.000000     1.000000
#
#              recov
# count  1085.000000
# mean      0.146544
# std       0.353814
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
total_of_rows = df.shape[0]
age_average = round(description.iloc[1,1],2)
death_average = round(description.iloc[1,4],4)
recovery_average = round(description.iloc[1,5],4)

# %%
print("The previous table quickly shows that gladly, it was more people the ones who recovered than the ones who died.")
print(f'The total of rows in this dataframe is {total_of_rows}, which is equivalent to the number of patients. We can also appreciate that the average age for total of the data base is {age_average} years old.')
print(f'In average, out of the {total_of_rows} patients, {death_average}% died and {recovery_average}% recovered from COVID 19')
# Out:
# The previous table quickly shows that gladly, it was more people the ones who recovered than the ones who died.
# The total of rows in this dataframe is 1085, which is equivalent to the number of patients. We can also appreciate that the average age for total of the data base is 49.48 years old.
# In average, out of the 1085 patients, 0.0581% died and 0.1465% recovered from COVID 19

# %%
print(df.dtypes)
# Out:
# id              int64
# location       object
# country        object
# gender         object
# age           float64
# sym_on         object
# hosp_vis       object
# vis_wuhan       int64
# from_wuhan    float64
# death           int64
# recov           int64
# symptom1       object
# symptom2       object
# symptom3       object
# symptom4       object
# symptom5       object
# symptom6       object
# dtype: object

# %% [markdown]
# B. DATA ANALYSIS:

# %% [markdown]
# In order for me to be able to analyze the data provided by the professor, it needs to be preprocessed and some of the data types need to be changed so that they can be manipulated.
#
# To achieve that, I have to use:

# %%
# To drop any columns I need .drop():
df = df.drop('id', axis=1)

# %%
# To fill out any empty or missing values
df = df.fillna(np.nan,axis=0)
# To change any String to a Numerical Value so that the Machine Learning Model successfully treats the data as numbers I have to use LabelEncoder, to encode categorical variables (STR) as numerical values.

import numpy as np
import pandas as pd
import datetime as dt
import sklearn
from scipy import stats
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score as rs
from sklearn.metrics import precision_score as ps
from sklearn.metrics import f1_score as fs
from sklearn.metrics import log_loss
encoder = preprocessing.LabelEncoder()

# %% [markdown]
# **Title Page**
# Proposal for TinyML-Based Application on Apple Watch
# Developed by [Your Name]
# Date of Submission: [Date]
#
# **Executive Summary**
# This proposal outlines the development of a TinyML-based application for Apple Watch aimed at promoting wellness, preventing illness, and keeping users active. Leveraging the power of TinyML on wearable devices like the Apple Watch eliminates the need for additional hardware investments, making wellness support accessible to a wider audience. The application will track user activity, provide personalized suggestions for maintaining health, and offer real-time feedback on activity levels.
#
# **ML Application and Architecture**
# The application aims to promote wellness and prevent illness by utilizing machine learning to analyze user activity data collected from sensors embedded in the Apple Watch. It will monitor various metrics such as heart rate, movement, and exercise patterns to provide personalized recommendations for staying active and healthy. The architecture involves data collection, model training, and inference stages, all executed within the Apple Watch environment.
#
# **Data Set and Acquisition Strategy**
# The training and testing data for the ML model will be obtained through various sources, including user-generated data collected from the sensors of the Apple Watch. Data collection will involve capturing user activity data, such as heart rate variations, step counts, and workout sessions, using the built-in sensors of the Apple Watch. Privacy and ethical considerations will be prioritized, ensuring compliance with data protection laws and user consent norms.
#
# **Model Training and Features**
# The ML model will be trained using Edge Impulse, a TinyMLaaS platform, which utilizes TensorFlow and Keras for model training and deployment. Feature extraction from sensor data, including time series data from motion sensors and biometric data from heart rate sensors, will be crucial for generating reliable ML models. Various learning techniques, such as neural networks and transfer learning, will be explored to classify user activity patterns and provide personalized wellness recommendations.
#
# **Evaluation of Model Performance and Improving Accuracy**
# Model performance will be evaluated using metrics like precision, recall, and F1-score, with a focus on increasing accuracy and reliability in detecting user activity patterns. Data augmentation techniques will be applied to enhance the diversity and representativeness of the training dataset. The model's performance on the Apple Watch hardware will be monitored to ensure compatibility and efficiency.
#
# **Risks, Limitations and Advantages**
# Embedding ML in wearable devices like the Apple Watch poses risks such as probabilistic estimates, computational intensity, and data acquisition challenges. However, advantages like convenience, accessibility, and real-time feedback make it a promising approach for promoting wellness and preventing illness.
#
# **Project Plan**
# 1. Set up Edge Impulse developer account
# 2. Acquire training and testing data from Apple Watch sensors
# 3. Train ML model using Edge Impulse
# 4. Evaluate and refine model performance on Apple Watch hardware
# 5. Export ML model code for deployment on Apple Watch
#
# **Investment**
# The primary investment for this project lies in time and intellectual resources, with access to the Edge Impulse platform being free. No additional hardware investments are required, as the application will be implemented on the existing Apple Watch.
#
# **Responsible Artificial Intelligence**
# Responsible AI licensing will be adopted to ensure ethical use of the ML application on the Apple Watch, prohibiting its misuse for harmful purposes. End-user and source-code licenses will reflect the commitment to positive impact and user privacy.
#
# **References**
# [List of references following APA style]
#
# [Additional content to reach 1,200 words can be added here, such as further elaboration on the features, benefits, or potential applications of the proposed TinyML-based application for wellness and illness prevention on the Apple Watch.]

# %%
df['location'] = encoder.fit_transform(df['location'].astype(str))
df['country'] = encoder.fit_transform(df['country'].astype(str))
df['gender'] = encoder.fit_transform(df['gender'].astype(str))
# df[['symptom1']] = encoder.fit_transform(df['symptom1'].astype(str))
# df[['symptom2']] = encoder.fit_transform(df['symptom2'].astype(str))
# df[['symptom3']] = encoder.fit_transform(df['symptom3'].astype(str))
# df[['symptom4']] = encoder.fit_transform(df['symptom4'].astype(str))
# df[['symptom5']] = encoder.fit_transform(df['symptom5'].astype(str))
# df[['symptom6']] = encoder.fit_transform(df['symptom6'].astype(str))

#On the other hand, to handle dates the data needs to be passed as datetime

df['sym_on'] = pd.to_datetime(df['sym_on'])
df['hosp_vis'] = pd.to_datetime(df['hosp_vis'])
df['sym_on']= df['sym_on'].map(dt.datetime.toordinal)
df['hosp_vis']= df['hosp_vis'].map(dt.datetime.toordinal)
df['diff_sym_hos']= df['hosp_vis'] - df['sym_on']

# %% [markdown]
# REVIEWS TO BE ANALYZED

# %%
import pandas as pd

# Define the reviews
reviews = [
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? it is a good brand as I see it.",
    "WHAT CAN THIS BRAND MOST IMPROVE? Your customer service and contractors",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Simplicity and elegance of design",
    "WHAT CAN THIS BRAND MOST IMPROVE? Customer service is truly horrible",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Innovative sustainability and continual improvement",
    "WHAT CAN THIS BRAND MOST IMPROVE? Customer service and after sale service, and spare parts sales",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? I love IKEA, it has been part of my home since I can remember!!",
    "WHAT CAN THIS BRAND MOST IMPROVE? Worst customer service ever. After being a loyal customer for over 25 years, I will never shop at IKEA again. I will discourage everyone I influence from shopping at IKEA",
    "WHAT CAN THIS BRAND MOST IMPROVE? It has to become more sustainable",
    "WHAT CAN THIS BRAND MOST IMPROVE? Train the employees and managers",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? I love that they set up little apartments to give you great ideas",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Low-cost prices and product varieties",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? I value customer service they provide",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? I hope they can continue the good work.",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? I WAS, I AM, AND FOREVER IKEA'S FAN. CONTINUE TO INSPIRE!",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Design + Functionality + affordable products",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? I feel like home in IKEA",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? The quality of the product is very good and all types of products are available",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? The variety of items at low prices",
    "WHAT CAN THIS BRAND MOST IMPROVE? I have been an Ikea customer for 20 years & most of my house is outfitted with Ikea products. I'm sorry to say that I'm done. I've tried to place an order numerous times. Your website is not consistent with availability, even ordering over the phone has resulted in canceled orders due to stock.",
    "WHAT CAN THIS BRAND MOST IMPROVE? Advising customers on significant price hikes!",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Global reach, focus on design and aesthetics, good quality, reasonable prices. Scandinavian culture",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Product design, functionality, and minimalistic design",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? My 2015, Optima was a beautiful ride reliable but when put in for a recall at 89,000 miles to keep motor from blowing Was OK until the motor blew it 105,000 was unable to communicate with the dealership in anyway they wanted $7000 to put a new motor in the vehicle with a warranty of 12 months or 12,",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? The fact that it's built to be adaptable.",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Their high quality for low prices",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? The quality of the products",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Design and practicality are what I value the most.",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Great brand and user experience",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Atmosphere, service, conditions, goods, and etc",
    "WHAT CAN THIS BRAND MOST IMPROVE? Racial profiling customers and discrimination",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Functional Design, affordability, modularity, product families",
    "WHAT CAN THIS BRAND MOST IMPROVE? Everything needs improving. Get to it.",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? The diversity in products and affordability",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Price-quality balance, customer support, variety.",
    "WHAT CAN THIS BRAND MOST IMPROVE? IKEA is super big, would appreciate it if you can find a way to make IKEA not a super long walking shop, some ways of easier transportation inside and public chairs for customers to relax would be greatly appreciated.",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Sticking to its core business model, cheap, and easy",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Great customer service and great prices",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? quality/price, design, experience buying products in the store",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Value and great customer service.",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Good design at a good price",
    "WHAT DO YOU VALUE MOST ABOUT THIS BRAND? Comfortable, affordable, nice design furniture"]

# %%
# Create a DataFrame
df = pd.DataFrame(reviews, columns=['Review'])

# Extract aspects and reviews
df['Aspect'] = df['Review'].apply(lambda x: x.split('?')[0])
df['Review'] = df['Review'].apply(lambda x: x.split('?')[1])

# Perform basic analysis
# Count the frequency of different aspects
aspect_counts = df['Aspect'].value_counts()

# Display the counts
print("Frequency of different aspects mentioned by customers:\n", aspect_counts)

# Visualization (for example, a bar plot)
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
aspect_counts.plot(kind='bar')
plt.title('Frequency of Different Aspects Mentioned by Customers')
plt.xlabel('Aspect')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
# Out:
# Frequency of different aspects mentioned by customers:
#  WHAT DO YOU VALUE MOST ABOUT THIS BRAND    31
# WHAT CAN THIS BRAND MOST IMPROVE           11
# Name: Aspect, dtype: int64

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import matplotlib.pyplot as plt

# Download NLTK resources (only need to run this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import matplotlib.pyplot as plt

# Download NLTK resources (only need to run this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to filter words based on their part-of-speech tag
def filter_words(review):
    tokens = word_tokenize(review)
    tagged = pos_tag(tokens)
    filtered_words = [word.lower() for word, tag in tagged if tag.startswith('JJ') or word.lower() in {'good', 'great', 'excellent', 'bad', 'horrible', 'terrible', 'awful'}]
    return filtered_words

# Apply the function to each review and count word frequencies
filtered_reviews = df['Review'].apply(filter_words)
word_counts = filtered_reviews.apply(Counter)

# Find the most common words/aspects in each review
most_common_words = filtered_reviews.apply(lambda x: [word for word, _ in Counter(x).most_common(3)])

# Plot the most common words/aspects
plt.figure(figsize=(16, 8))
common_words_flat = [word for sublist in most_common_words for word in sublist]
word_freq = Counter(common_words_flat)
word_freq_df = pd.DataFrame(word_freq.most_common(), columns=['Word', 'Frequency'])

# Capitalize the words
word_freq_df['Word'] = word_freq_df['Word'].apply(lambda x: x.capitalize())

plt.bar(word_freq_df['Word'], word_freq_df['Frequency'], color='skyblue')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Most Common Adjectives and Positive/Negative Words in Reviews')
plt.xlabel('Words/Aspects')
plt.ylabel('Frequency')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import matplotlib.pyplot as plt

# Download NLTK resources (only need to run this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Function to filter words based on their part-of-speech tag and remove specified words
def filter_words(review):
    tokens = word_tokenize(review)
    tagged = pos_tag(tokens)
    filtered_words = [word.lower() for word, tag in tagged if tag.startswith('JJ') or word.lower() in {'good', 'great service', 'excellent', 'bad', 'horrible attention', 'terrible', 'awful', 'affordable', 'reasonable', 'easy to build', 'house example', 'variety', 'not online stock', 'global reach', 'reliable warranty', 'brand experience', 'long walks', 'great design', 'quality'}]
    # Replace specified words with their desired alternatives
    filtered_words = ['great service' if word == 'great' else word for word in filtered_words]
    filtered_words = ['horrible attention' if word == 'horrible' else word for word in filtered_words]
    filtered_words = ['bad spare parts' if word == 'spare' else word for word in filtered_words]
    filtered_words = ['house replica' if word == 'little' else word for word in filtered_words]
    filtered_words = ['variety' if word == 'available' else word for word in filtered_words]
    filtered_words = ['not online stock' if word == 'sorry' else word for word in filtered_words]
    filtered_words = ['global reach' if word == 'global' else word for word in filtered_words]
    filtered_words = ['reliable warranty' if word == 'unable' else word for word in filtered_words]
    filtered_words = ['brand experience' if word == 'user' else word for word in filtered_words]
    filtered_words = ['long walks' if word == 'big' else word for word in filtered_words]
    filtered_words = ['great design' if word == 'nice' else word for word in filtered_words]
    filtered_words = ['discrimation' if word == 'racial' else word for word in filtered_words]

    # Combine 'affordable' and 'reasonable'
    filtered_words = ['affordable' if word in {'affordable', 'reasonable'} else word for word in filtered_words]
    # Combine 'adaptable', 'easier', and 'easy'
    filtered_words = ['easy to build' if word in {'adaptable', 'easier', 'easy'} else word for word in filtered_words]
    filtered_words = ['variety' if word in {'variety', 'continual'} else word for word in filtered_words]
    return filtered_words

# Apply the function to each review and count word frequencies
filtered_reviews = df['Review'].apply(filter_words)
word_counts = filtered_reviews.apply(Counter)

# Find the most common words/aspects in each review
most_common_words = filtered_reviews.apply(lambda x: [word for word, _ in Counter(x).most_common(3)])

# Determine if a review is positive or negative based on the presence of positive or negative words
positive_words = {'good', 'great service', 'excellent', 'affordable', 'reasonable', 'easy to build', 'variety', 'global reach', 'reliable warranty', 'great design', 'quality'}
negative_words = {'bad', 'horrible attention', 'terrible', 'awful', 'not online stock', 'long walks'}
review_sentiments = filtered_reviews.apply(lambda x: 'Positive' if any(word in positive_words for word in x) else ('Negative' if any(word in negative_words for word in x) else 'Neutral'))

# Plot the most common words/aspects with colors indicating sentiment
plt.figure(figsize=(12, 8))
# common_words_flat = [word for sublist in most_common_words for word in sublist]
common_words_flat = [word for sublist in most_common_words for word in sublist if word != 'Most']  # Remove 'Most'

word_freq = Counter(common_words_flat)
word_freq_df = pd.DataFrame(word_freq.most_common(), columns=['Word', 'Frequency'])

# Capitalize the words
word_freq_df['Word'] = word_freq_df['Word'].apply(lambda x: x.capitalize())

# Assign colors based on sentiment
colors = ['green' if sentiment == 'Positive' else 'red' if sentiment == 'Negative' else 'gray' for sentiment in review_sentiments]

plt.bar(word_freq_df['Word'], word_freq_df['Frequency'], color=colors)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Most Common Adjectives and Positive/Negative Words in Reviews')
plt.xlabel('Words/Aspects')
plt.ylabel('Frequency')
plt.show()

# %%
# Function to filter words based on their part-of-speech tag and remove specified words
def filter_words(review):
    tokens = word_tokenize(review)
    tagged = pos_tag(tokens)
    filtered_words = [word.lower() for word, tag in tagged if tag.startswith('JJ') or word.lower() in {'good', 'great service', 'excellent', 'bad', 'horrible attention', 'terrible', 'awful', 'affordable', 'reasonable', 'easy to build', 'house example', 'variety', 'not online stock', 'global reach', 'reliable warranty', 'brand experience', 'long walks', 'great design', 'quality', 'innovative', 'sustainable', 'consistent', 'minimalistic', 'beautiful', 'comfortable', 'discrimination'}]
    # Replace specified words with their desired alternatives
    filtered_words = ['great service' if word == 'great' else word for word in filtered_words]
    filtered_words = ['horrible attention' if word == 'horrible' else word for word in filtered_words]
    filtered_words = ['bad spare parts' if word == 'spare' else word for word in filtered_words]
    filtered_words = ['house example' if word == 'little' else word for word in filtered_words]
    filtered_words = ['variety' if word == 'available' else word for word in filtered_words]
    filtered_words = ['not online stock' if word == 'sorry' else word for word in filtered_words]
    filtered_words = ['global reach' if word == 'global' else word for word in filtered_words]
    filtered_words = ['reliable warranty' if word == 'unable' else word for word in filtered_words]
    filtered_words = ['brand experience' if word == 'user' else word for word in filtered_words]
    filtered_words = ['long walks' if word == 'big' else word for word in filtered_words]
    filtered_words = ['great design' if word == 'nice' else word for word in filtered_words]
    filtered_words = ['discrimination' if word == 'racial' else word for word in filtered_words]
    filtered_words = [word for word in filtered_words if word not in {'most', 'super'}]  # Remove 'Most' and 'Super'
    # Combine 'affordable' and 'reasonable'
    filtered_words = ['affordable' if word in {'affordable', 'reasonable','low', 'cheap', 'low-cost'} else word for word in filtered_words]
    # Combine 'adaptable', 'easier', and 'easy'
    filtered_words = ['easy to build' if word in {'adaptable', 'easier', 'easy'} else word for word in filtered_words]
    filtered_words = ['variety' if word in {'variety', 'continual'} else word for word in filtered_words]
    return filtered_words

# Apply the function to each review and count word frequencies
filtered_reviews = df['Review'].apply(filter_words)
word_counts = filtered_reviews.apply(Counter)

# Find the most common words/aspects in each review
most_common_words = filtered_reviews.apply(lambda x: [word for word, _ in Counter(x).most_common(3)])

# Determine if a review is positive or negative based on the presence of positive or negative words
positive_words = {'good', 'great service', 'excellent', 'affordable', 'reasonable', 'easy to build', 'variety', 'global reach', 'reliable warranty', 'great design', 'quality', 'innovative', 'sustainable', 'consistent', 'minimalistic', 'beautiful', 'comfortable'}
negative_words = {'bad', 'horrible attention', 'terrible', 'awful', 'not online stock', 'long walks', 'discrimination'}
review_sentiments = filtered_reviews.apply(lambda x: 'Positive' if any(word in positive_words for word in x) else ('Negative' if any(word in negative_words for word in x) else 'Neutral'))

# Plot the most common words/aspects with colors indicating sentiment
plt.figure(figsize=(16, 8))
common_words_flat = [word for sublist in most_common_words for word in sublist]

word_freq = Counter(common_words_flat)
word_freq_df = pd.DataFrame(word_freq.most_common(), columns=['Word', 'Frequency'])

# Capitalize the words
word_freq_df['Word'] = word_freq_df['Word'].apply(lambda x: x.capitalize())

# Assign colors based on sentiment
colors = ['green' if sentiment == 'Positive' else 'red' if sentiment == 'Negative' else 'gray' for sentiment in review_sentiments]

# Remove "Most"
word_freq_df = word_freq_df[word_freq_df['Word'] != 'Most']

plt.bar(word_freq_df['Word'], word_freq_df['Frequency'], color=colors)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Most Common Adjectives and Positive/Negative Words in Reviews')
plt.xlabel('Words/Aspects')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ASSESSMENT 1 | BUSINESS BY DESIGN RESEARCH PROJECT

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Data for visualization
# Feel free to replace with your own data as needed

# IKEA's history timeline
timeline_data = {'Year': [1943, 1975], 'Event': ['IKEA\n founded', 'IKEA\n in\n Australia']}
# Product categories pie chart
product_categories = {'Furniture': 30, 'Home Décor': 15, 'Kitchen and Dining': 20, 'Bedroom Solutions': 10,
                      'Bathroom Furnishings': 5, "Children's Furniture and Accessories": 10, 'Outdoor Furniture': 5,
                      'Storage Solutions': 10, 'Assembly Services': 2, 'Home Delivery': 3}
# Competitors comparison bar chart
competitors = {'Harvey Norman': 25, 'Fantastic Furniture': 20, 'Freedom Furniture': 15, 'IKEA': 40}
# Word cloud of IKEA's vision, mission, and values
word_cloud_text = "create better everyday life many people affordable functional well-designed sustainable growth customer satisfaction innovation"
# Persona profiles
personas = {'Young Professional (Sarah)': {'Budget': 'Low', 'Style Preference': 'Modern', 'Needs': 'Affordable furniture'},
            'Family Man (David)': {'Budget': 'Medium', 'Style Preference': 'Durable', 'Needs': 'Practical furniture'},
            'Interior Design Enthusiast (Emily)': {'Budget': 'High', 'Style Preference': 'Unique', 'Needs': 'Customizable furniture'}}
# Empathy map
empathy_map = {'What They Say': ['I need furniture that fits my budget but still looks chic.',
                                 'I want furniture that can withstand the wear and tear of family life.',
                                 'I’m searching for unique pieces that reflect my design aesthetic.'],
               'What They Do': ['Researches online and compares prices before making a purchase.',
                                'Visits the IKEA store to physically examine the furniture’s quality.',
                                'Follows interior design influencers on social media for inspiration.'],
               'What They Think and Feel': ['Worried about finding affordable furniture without compromising style.',
                                            'Concerned about choosing furniture that is safe for his children.',
                                            'Excited about the opportunity to customize her living space.'],
               'Pain Points': ['Limited budget restricts her options for furniture selection.',
                               'Frustrated with the lack of durable furniture options within his budget.',
                               'Disappointed by the lack of unique furniture pieces in mainstream stores.']}

# Visualizations

# Timeline of IKEA's history
plt.figure(figsize=(10, 4))
plt.plot(timeline_data['Year'], [1]*len(timeline_data['Year']), 'o', markersize=10)
plt.yticks([])
plt.title('IKEA\'s History Timeline')
for i, txt in enumerate(timeline_data['Event']):
    plt.text(timeline_data['Year'][i], 1.05, txt, ha='center')
plt.show()

# Product categories pie chart
plt.figure(figsize=(8, 8))
plt.pie(product_categories.values(), labels=product_categories.keys(), autopct='%1.1f%%', startangle=140)
plt.title('IKEA\'s Product Categories')
plt.show()

# Define the data (competitors and their market share)
competitors = {
    'Harvey Norman': 20,
    'Fantastic Furniture': 30,
    'Freedom Furniture': 25,
    'IKEA': 35  # Adding IKEA back to the competitors list
}

# Create a custom color palette with a gradient from purple to dark purple
colors = sns.color_palette("Purples_r", len(competitors))

# Competitors comparison bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=list(competitors.keys()), y=list(competitors.values()), palette=colors)
plt.title('Competitors Comparison')
plt.ylabel('Market Share (%)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()


# Word cloud of IKEA's vision, mission, and values
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(word_cloud_text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of IKEA\'s Vision, Mission, and Values')
plt.show()

# Persona profiles
plt.figure(figsize=(10, 6))
sns.heatmap([[0 if v != 'High' else 1 for k, v in personas[persona].items()] for persona in personas.keys()],
            annot=True, cmap='coolwarm', yticklabels=personas.keys())
plt.title('Persona Profiles')
plt.ylabel('Personas')
plt.xlabel('Attributes (Budget, Style Preference, Needs)')
plt.show()
import matplotlib.pyplot as plt

# Empathy map data
empathy_map = {
    'What They Say': [
        "I need furniture that fits my budget but still looks chic.",
        "I want furniture that can withstand the wear of family life.",
        "I’m searching for unique pieces that reflect my design aesthetic."
    ],
    'What They Do': [
        "Researches online and compares prices before making a purchase.",
        "Visits the IKEA store to physically examine the furniture’s quality.",
        "Follows interior design influencers on social media for inspiration."
    ],
    'What They Think and Feel': [
        "Concerned about affordability without sacrificing style.",
        "Concerned about choosing furniture that is safe for his children.",
        "Excited about the opportunity to customize her living space."
    ],
    'Pain Points': [
        "Limited budget restricts her options for furniture selection.",
        "Disappointed by the lack of uniqueness in mainstream stores.",
        "Frustrated with the lack of durable furniture options within budget."
    ]
}

# Function to plot empathy map
def plot_empathy_map(empathy_map):
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    fig.subplots_adjust(hspace=0.6, wspace=0.4)  # Adjust spacing between subplots
    plt.suptitle('Empathy Map', fontsize=16, fontweight='bold')

    for ax, (title, data) in zip(axs.flat, empathy_map.items()):
        ax.set_title(title, fontsize=14, fontweight='bold')
        ax.axis('off')

        # Add styled box for each section
        ax.text(0.05, 0.95, title, fontsize=12, fontweight='bold', ha='left', va='top')
        ax.add_patch(plt.Rectangle((0, 0), 1, 1, color='lightgrey', alpha=0.3, linewidth=2, edgecolor='black'))

        # Add text inside the box
        text = '\n'.join([f"{j+1}. {item}" for j, item in enumerate(data)])
        ax.text(0.05, 0.85, text, fontsize=11, ha='left', va='top')

    plt.show()

# Plot the empathy map
plot_empathy_map(empathy_map)
# Out:
# <ipython-input-61-f57b9e8373c2>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(competitors.keys()), y=list(competitors.values()), palette=colors)
# <ipython-input-61-f57b9e8373c2>:127: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.add_patch(plt.Rectangle((0, 0), 1, 1, color='lightgrey', alpha=0.3, linewidth=2, edgecolor='black'))

# %%
import matplotlib.pyplot as plt

# Empathy map data
empathy_map = {
    'What They Say': [
        "I need furniture that fits my budget but still looks chic.",
        "I want furniture that can withstand the wear of family life.",
        "I’m searching for unique pieces that reflect my design aesthetic."
    ],
    'What They Do': [
        "Researches online and compares prices before making a purchase.",
        "Visits the IKEA store to physically examine the furniture’s quality.",
        "Follows interior design influencers on social media for inspiration."
    ],
    'What They Think and Feel': [
        "Concerned about affordability without sacrificing style.",
        "Concerned about choosing furniture that is safe for his children.",
        "Excited about the opportunity to customize her living space."
    ],
    'Pain Points': [
        "Limited budget restricts her options for furniture selection.",
        "Disappointed by the lack of uniqueness in mainstream stores.",
        "Frustrated with the lack of durable furniture options within budget."
    ]
}

# Function to plot empathy map
def plot_empathy_map(empathy_map):
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    fig.subplots_adjust(hspace=0.6, wspace=0.4)  # Adjust spacing between subplots
    plt.suptitle('Empathy Map', fontsize=16, fontweight='bold')

    for ax, (title, data) in zip(axs.flat, empathy_map.items()):
        ax.set_title(title, fontsize=14, fontweight='bold')
        ax.axis('off')

        # Add styled box for each section
        ax.text(0.05, 0.95, title, fontsize=12, fontweight='bold', ha='left', va='top')
        ax.add_patch(plt.Rectangle((0, 0), 1, 1, color='lightgrey', alpha=0.3, linewidth=2, edgecolor='black'))

        # Add text inside the box
        text = '\n'.join([f"{j+1}. {item}" for j, item in enumerate(data)])
        ax.text(0.05, 0.85, text, fontsize=11, ha='left', va='top')

    plt.show()

# Plot the empathy map
plot_empathy_map(empathy_map)
# Out:
# <ipython-input-58-420a5e591421>:39: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.add_patch(plt.Rectangle((0, 0), 1, 1, color='lightgrey', alpha=0.3, linewidth=2, edgecolor='black'))
